# %% [markdown]
# - Quel est le prix moyen après réduction ?
# - Quel est le pourcentage de réduction moyen ?
# - Quelle est la note (rating) moyenne de tous les produits ?
# - Quel est le produit le moins cher ? Le plus cher ?

# %%
# %run E:/DATA_ANALYST_KAGGLE/amazon-data-analyst/common/utils.ipynb
df = read_data("E:/DATA_ANALYST_KAGGLE/amazon-data-analyst/data/amazon.csv")
df = cleaning_data(df)
df = extract_main_category(df)
print(f"length of dataframe => {len(df)}")
# Out:
# Importing successfully
# length of dataframe => 1465

# %%
all_products_with_rating_greater_or_equal_4 = df[df["rating"] >= 4.5]
print(f"length of N°01 => {len(all_products_with_rating_greater_or_equal_4)}")
# Out:
# length of N°01 => 104

# %%
all_product_with_discount_greater_70 = df[df["discount_percentage"] > 70]
print(f"length of N°02 => {len(all_product_with_discount_greater_70)}")
# Out:
# length of N°02 => 219

# %%
all_product_with_discounted_price_less_200 = df[df["discounted_price"] < 200]
print(f"length of N°03 => {len(all_product_with_discounted_price_less_200)}")
# Out:
# length of N°03 => 199
